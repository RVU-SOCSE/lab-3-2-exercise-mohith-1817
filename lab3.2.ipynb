# %%
z={1,4,2,7,3,8,3}
y={2,5,8,3,6,9}

z.add(9)
print(z)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
h=z.copy()
h
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
z.union(y)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
z.intersection(y)
# Out:
# {2, 3, 8, 9}

# %%
z.difference(y)
# Out:
# {1, 4, 7}

# %%
y.difference(z)
# Out:
# {5, 6}

# %%
z.symmetric_difference(y)
# Out:
# {1, 4, 5, 6, 7}

# %%
z.discard(4)
z
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
z.update([10,20])
z
# Out:
# {1, 2, 3, 7, 8, 9, 10, 20}

# %%
z.isdisjoint(y)
# Out:
# False

# %%
z.issubset(y)
# Out:
# False

# %%
z.issuperset(y)
# Out:
# False

# %%
y.update([7,17,28,11])
y
# Out:
# {2, 3, 5, 6, 7, 8, 9, 11, 17, 28}
